# %%
import requests
from bs4 import BeautifulSoup
import time
import random
import csv
import pandas as pd

# %%
#Website URL INSERT LETTER WHERE THE # IS!! AFTER THE SLASH
url="https://www.azlyrics.com/g.html"

#collect artist names from page
page = requests.get(url)
soup = BeautifulSoup(page.content, 'lxml')
x = soup.find_all(class_="col-sm-6 text-center artist-col")

#initialize empty lists
links = []
artist_names = []

#fill link list and artist_names list
for col in x:
    g_tags = col.find_all("a")
    for item in g_tags:
        links.append(item.get('href'))
        artist_names.append(item.text)
        
#Create list of URLs
artist_urls = ["https://www.azlyrics.com/" + addition for addition in links]
#urls = []
#albums = []
songTitles = []
artistNames = []
#lyrics = []
#year = []
counter = 0
z=list(zip(artist_names, artist_urls))
#print(z)
#Collect Data
allData = []

for item in z:
    artist_name = item[0]
    url = item[1]
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'lxml')
    divs = soup.find_all("div")
    current_album=""
    for div in divs:
        if div.has_attr("class"):
            if div.attrs["class"][0]=="album":
                current_album = div.text
            elif div.attrs["class"][0] == "listalbum-item":
                endLink = div.a.get("href")
                songURL = "https://www.azlyrics.com/" + endLink[3:]
                curr_song = div.text
                try:
                    page1 = requests.get(songURL)
                    soupp = BeautifulSoup(page1.content, 'lxml')
                    x = soupp.find('div', {'class': 'col-xs-12 col-lg-8 text-center'})
                    y = x.find_all('div')
                    curr_year = current_album[-5:-1]
                    lyrics = y[5].text

                    try:
                        year = int(curr_year)
                        yearUP = str(year)
                        Row = [artist_name, current_album, yearUP, curr_song, lyrics]
                        allData.append(Row)
                        print(Row)
                        counter += 1
                        print(str(350-counter) + ' Songs Left')

                    except:
                        print('Invalid Year, Ignoring Song')
                except:
                    print('Could Not Collect Page Data')

                t = random.uniform(4,12)
                print('Pausing ' + str(t) + ' Seconds')
                print(counter)
                time.sleep(t)
                
        if counter == 350:
            break
    if counter == 350:
        break

with open('songLyricsALL.csv', 'w', encoding="utf-8", newline='') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(("Artist", "Album", "Year", "Song Title", "Lyrics"))
    wr.writerows(allData)
myfile.close()
# Out:
# ['G4 Boyz', 'album: "Banksy" (2013)', '2013', 'Hair, Nails, Makeup', "\n\r\nI want my ass fat, my nails paint, my pussy ate\nMy car noh, my titties in, my... is\nYou're ready for that daddy\nI want my big suck, my lunch made, my mill made\nThat pussy wet, that ass fat, that ass check\nYou ready for that mama\nI want my ass fat, my nails paint, my pussy ate\nMy car noh, my titties in, my... is\nYou're ready for that daddy\nI want my big suck, my lunch made, my mill made\nThat pussy wet, that ass fat, that ass check\nYou ready for that mama\n\nOkay oh oh, like the way you do that\nAss your fat go get your grab and cold that\nShe say she dancin 'cause she sleeping off for college\nBitch ain't' playin but we knew it fucking diamond, stop lying\n5, 10, 20, 50 get it girl, get it girl\n5, 10, 20, 50 get it girl, get it girl\nAll this fuck tricks man, is your world, is your world\nAll this fuck tricks man, is your world, is your world\nStacks at the... baby girl I'm a baller\nTake it to the crib and I will never call her\nAll I do is piper you want a wife\nTake her to the crib like a down, like a lifer\n\nShe don't fuck with bro niggas hell not, hell not\nShe don't fuck with bro niggas hell not, hell not\nShe don't fuck with bro niggas hell not, hell not\nShe wants her hair makeup and my nails done, nails done\n\nLike big Sean I'm like...\nPut the money up and I'm sodded\nI'm on the wall and I'm posted\nShe pussy damn I'm toasted\nNigga my circle got no squares\nI'm sick like I got no cares\nI take her back to my own...\nAnd I bip bip like no swear\nBad bitch, bad bitch hit me up like...\nHit it once like no...\nAnd I need... to no average she talk shit\nI slap bitch I'm pimpin here, I'm pimpin here\nShe suck me up like left in...\nWhen I kill the pussy like...\n\nOkay I love how she get sexy on\nShe trash like a baby shawn\nI'ma strap like a nasty on\nI am the kind I am the dawn\nShe love the way I do my thing\nCome back like a boomerang\nI take her to the far blue\nWill she give me super hit\nYes I sue a... baby girl I'm about to breathe\nHit you like a Babilon\nI run the streets like a marathon\nGoing in, I'm going out\nI'm.and ain't' no drop\nShe says no fuck with bro niggas\nI told that bitch I ain't' the one\n\nShe don't fuck with bro niggas hell not, hell not\nShe don't fuck with bro niggas hell not, hell not\nShe don't fuck with bro niggas hell not, hell not\nShe wants her hair makeup and my nails done, nails done\nShe don't fuck with bro niggas I'm bout my...\nShe don't fuck with bro niggas I'm bout my...\nShe don't fuck with bro niggas I'm bout my...\n"]
# 349 Songs Left
# Pausing 8.323988522503367 Seconds
# 1
# ['G4 Boyz', 'album: "Ballin Wit No Deal 2" (2014)', '2014', 'Bricks', "\n\r\nYou know we got bricks too huh\nNew rollie I just cop bought it all from bricks\nNew V that I just dropped bought it all from bricks\nFlash screens up in the spot\nBought it all from bricks\nI'm the man from round here\n\nI'm the man around here bought it all from bricks\nBricks, bricks, bricks, bricks, bricks\nBought it all from\nBricks, bricks, bricks, bricks, bricks\nBought it all from bricks\nBricks, bricks, bricks, bricks, bricks\nI'm the man around here bought it all from bricks\nBricks, bricks, bricks, bricks, bricks\nSold it all from for bricks\nBricks, bricks, bricks, bricks, bricks\nSold it up for bricks\nBricks, bricks, bricks, bricks, bricks\n\nHoney's is a chick, I bought it all from bricks wiping on, wiping on pack\nNow you make no sense, make no sense\nG. flow, when the G flow\nWhen we ball on that bricks suck nigga\nPolly try to hit a nigga with a recording, got evidence\nFuck, go\n\nI'm the man around here ballin on for bricks\nI'm the man around here ballin on for bricks\nBallin on for\nBricks, bricks, bricks, bricks, bricks\nBallin on for\nBricks, bricks, bricks, bricks, bricks\nI'm the man around here ballin on for bricks\n\nI ball the 'of bricks\nI'm 'bout to add it some bricks\nThe Gucci, the Louie, the DG don't mess with my 'I brake\nIf they hit me I''mma say it on\nSmoking OG cause it metical\nI get the top of the 'happening and you gotta be putting on the\nRollers go for selling bricks\nAll roll for the bricks\nTrapping to the rapper cause I had to make it all change\nAsking me when I'mma quit\nThe day they want it and they have it all\nI got rich selling bridge\nMaybe they came from a trapping bricks\n\nNew rollie I just ballin it up some bricks\nNew valley that's just drop ballin on for drops\nFlash crisps up in the spot\nBall it up for bricks\nI'm the man around here ballin on for bricks\nBricks, bricks, bricks, bricks, bricks\nBallin on for bricks\nBricks, bricks, bricks, bricks, bricks\nBallin on for bricks\nBricks, bricks, bricks, bricks, bricks\nI'm the man around here ballin on for bricks\nBallin on for bricks\n\nThey we love this girl you love it\nI can make you hot in public\nSay you're not in love with dice\nBitch you know you fucking bugging\nListing like it's blazer\nWaste it like a bizarre\nThen a couple hinny that we miss [?] with the '\nBalling with no dilly, dilly\nWiping up a milly, milly\nBaking up a cake, yeah they call me mister wiper\nIf you sniff code baby I can be your pusher\nSmoking pure, end it all I then cal the action pusher\nMe, I'm a money nigga, use a bum bum, I'm really nigga\nLying nigga, crying nigga, your pocket is dying nigga\nBaby mama crying nigga\nCause you wising nothing nigga\nSaid she want me but I'm straight up, denying nigga\n\nNew rollie I just ballin it up some bricks\nNew valley that's just drop ballin on for drops\nFlash crisps up in the spot\nBall it up for bricks\nI'm the man around here ballin on for bricks\nBricks, bricks, bricks, bricks, bricks\nBallin on for bricks\nBricks, bricks, bricks, bricks, bricks\nBallin on for bricks\nBricks, bricks, bricks, bricks, bricks\nI'm the man around here ballin on for bricks\nBallin on for bricks\n\nHalf of break, whole break\nNiga I ain't fronting shit\nShe said she's in love with me but she ain't know my government\nShe in love with Benjamin, I'm in love with Benjamin\nShe in love with em cause the way I'll be spending\nRollin, rollin I'm on, diamond on my chain\nYour rolli probably fake\nIt's taking like a bomb, brokes nigga ain't me\nI can probably fuck your moms\nFuck nigga hate me\nI can probably fuck your moms\n\nNew rollie I just copped it bought it all from bricks\nNew valley that's just drop ballin on for drops\nFlash crisps up in the spot\nBall it up for bricks\nI'm the man around here ballin on for bricks\n"]
# 348 Songs Left
# Pausing 7.8935724060919545 Seconds
# 2
