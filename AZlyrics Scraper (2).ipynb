# %%
import requests
from bs4 import BeautifulSoup
import time
import random
import csv
import pandas as pd

# %%
#Website URL INSERT LETTER WHERE THE # IS!! AFTER THE SLASH
url="https://www.azlyrics.com/g.html"

#collect artist names from page
page = requests.get(url)
soup = BeautifulSoup(page.content, 'lxml')
x = soup.find_all(class_="col-sm-6 text-center artist-col")

#initialize empty lists
links = []
artist_names = []

#fill link list and artist_names list
for col in x:
    g_tags = col.find_all("a")
    for item in g_tags:
        links.append(item.get('href'))
        artist_names.append(item.text)
        
#Create list of URLs
artist_urls = ["https://www.azlyrics.com/" + addition for addition in links]
urls = []
#albums = []
songTitles = []
artistNames = []
#lyrics = []
#year = []
counter = 0
z=list(zip(artist_names, artist_urls))
#print(z)
#Collect Data
allData = []
for item in z:
    artist_name = item[0]
    url = item[1]
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'lxml')
    divs = soup.find_all("div")
    current_album=""
    for div in divs:
        if div.has_attr("class"):
            if div.attrs["class"][0]=="album":
                current_album = div.text
            elif div.attrs["class"][0] == "listalbum-item":
                endLink = div.a.get("href")
                songURL = "https://www.azlyrics.com/" + endLink[3:]
                curr_song = div.text
                page1 = requests.get(songURL)
                soupp = BeautifulSoup(page1.content, 'lxml')
                x = soupp.find('div', {'class': 'col-xs-12 col-lg-8 text-center'})
                y = x.find_all('div')
                curr_year = current_album[-5:-1]
                lyrics = y[5].text
                try:
                    year = int(curr_year)
                    yearUP = str(year)
                    Row = [artist_name, current_album, yearUP, curr_song, lyrics]
                    allData.append(Row)
                    print(Row[:4])
                    counter += 1
                    print(str(350-counter) + ' Songs Left')
                except:
                    print('Invalid Year, Ignoring Song')
                    
                t = random.uniform(4,10)
                print('Pausing ' + str(t) + ' Seconds')
                print(counter)
                time.sleep(t)
                
        if counter == 350:
            break
    if counter == 350:
        break
                
            
with open('songLyricsALL.csv', 'w', encoding="utf-8", newline='') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(("Artist", "Album", "Year", "Song Title", "Lyrics"))
    wr.writerows(allData)
    #print(D)
myfile.close()
# Out:
# ['G4 Boyz', 'album: "Banksy" (2013)', '2013', 'Hair, Nails, Makeup']
# 349 Songs Left
# Pausing 5.432833813235664 Seconds
# 1
# ['G4 Boyz', 'album: "Ballin Wit No Deal 2" (2014)', '2014', 'Bricks']
# 348 Songs Left
# Pausing 8.204885823763645 Seconds
# 2
# ['G4 Boyz', 'album: "Control Your Jealousy" (2015)', '2015', 'Alexander Wang']
# 347 Songs Left
# Pausing 6.699404475434299 Seconds
# 3
# ['G4 Boyz', 'album: "Control Your Jealousy" (2015)', '2015', "Can't Sit With Us"]
# 346 Songs Left
# Pausing 7.4012779654177185 Seconds
# 4
# ['G4 Boyz', 'album: "The African Plug" (2017)', '2017', 'The African Plug Intro']
# 345 Songs Left
# Pausing 9.375186193527242 Seconds
# 5
# ['G4 Boyz', 'album: "The African Plug" (2017)', '2017', 'Big Daddy']
# 344 Songs Left
# Pausing 9.239068041715601 Seconds
# 6
# ['G4 Boyz', 'album: "The African Plug" (2017)', '2017', 'Toma (Remix)']
# 343 Songs Left
# Pausing 7.422057054942669 Seconds
# 7
# Invalid Year, Ignoring Song
# Pausing 8.237209690627942 Seconds
# 7
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-7697356838de>", line 48, in <module>
#     page1 = requests.get(songURL)
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/requests/api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 343, in _make_request
#     self._validate_conn(conn)
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 839, in _validate_conn
#     conn.connect()
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py", line 344, in connect
#     ssl_context=context)
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py", line 347, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py", line 456, in wrap_socket
#     cnx.do_handshake()
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py", line 1914, in do_handshake
#     result = _lib.SSL_do_handshake(self._ssl)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/posixpath.py", line 395, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/posixpath.py", line 429, in _joinrealpath
#     if not islink(newpath):
#   File "/Users/theodore/opt/anaconda3/lib/python3.7/posixpath.py", line 171, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
